# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\stods\\git'

# %%
variable= pd.read_csv(r"C:\Users\stods\git\rates0017.csv")
variable
# Out:
#     Year Divorces   Population  RatePer1kpop
# 0   2017   787251    270423493           2.9
# 1   2016   776288    257904548           3.0
# 2   2015  800,909  258,518,265           3.1
# 3   2014  813,862  256,483,624           3.2
# 4   2013  832,157  254,408,815           3.3
# 5   2012  851,000  248,041,986           3.4
# 6   2011  877,000  246,273,366           3.6
# 7   2010  872,000  244,122,529           3.6
# 8   2009  840,000  242,610,561           3.5
# 9   2008  844,000  240,545,163           3.5
# 10  2007  856,000  238,352,850           3.6
# 11  2006  872,000  236,094,277           3.7
# 12  2005  847,000  233,495,163           3.6
# 13  2004  879,000  236,402,656           3.7
# 14  2003  927,000  243,902,090           3.8
# 15  2002  955,000  243,108,303           3.9
# 16  2001  940,000  236,416,762           4.0
# 17  2000  944,000  233,550,143           4.0

# %% [markdown]
# y  =[variable.Birth_rate]
# plt.legend(["Birth rate per year"])
# plt.xlabel('year')
# plt.ylabel('Birth rate')
# plt.show()

# %%
#Divorce rates
x_axis = np.arange(2000,2018, 1.0)
fig=plt.figure(figsize=(14, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(x_axis, variable.RatePer1kpop)
Year_Rate = plt.plot(x_axis, variable.RatePer1kpop, color="red", label="Divorce Rate" )
y_axis = ['RatePer1kpop']
plt.xlabel('Year') 
plt.ylabel('Percent of the population') 
plt.title('Dirvorce Rate')
plt.xticks(ticks = x_axis, labels = x_axis)
plt.grid()
plt.xlim(2000, 2017)
plt.tight_layout()
plt.savefig("DivorceRate.png")
plt.show()

# %%
#Marriage rates
Mrates= pd.read_csv(r"C:\Users\stods\git\Mrates.csv")
Mrates
# Out:
#     Year  Marriages   Population  MRateper1kpop
# 0   2017  2,236,496  325,719,178            6.9
# 1   2016  2,251,411  323,127,513            7.0
# 2   2015  2,221,579  321,418,820            6.9
# 3   2014  2,140,272  308,759,713            6.9
# 4   2013  2,081,301  306,136,672            6.8
# 5   2012  2,131,000  313,914,040            6.8
# 6   2011  2,118,000  311,591,917            6.8
# 7   2010  2,096,000  308,745,538            6.8
# 8   2009  2,080,000  306,771,529            6.8
# 9   2008  2,157,000  304,093,966            7.1
# 10  2007  2,197,000  301,231,207            7.3
# 11  2006  2,193,000  294,077,247            7.5
# 12  2005  2,249,000  295,516,599            7.6
# 13  2004  2,279,000  292,805,298            7.8
# 14  2003  2,245,000  290,107,933            7.7
# 15  2002  2,290,000  287,625,193            8.0
# 16  2001  2,326,000  284,968,955            8.2
# 17  2000  2,315,000  281,421,906            8.2

# %%
#Marriage rates
fig=plt.figure(figsize=(14, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(Mrates.Year, Mrates.MRateper1kpop)
Year_Rate, = plt.plot(Mrates.Year, Mrates.MRateper1kpop, color="red", label="Marriage Rate" )
y_axis = ['MRateper1kpop']
plt.xlabel('Year') 
plt.ylabel('Percent of the population') 
plt.title('Marriage Rate')
plt.xticks(ticks = x_axis, labels = x_axis)
plt.savefig("MarriageRate.png")
plt.grid()
plt.xlim(2000, 2017)
plt.tight_layout(0)
plt.show()

# %%
# Comparison
fig=plt.figure(figsize=(14, 6), dpi= 80, facecolor='w', edgecolor='k')
Marriage, = plt.plot(x_axis, Mrates.MRateper1kpop,color="blue", label="Marriages")
Divorces, = plt.plot(x_axis, variable.RatePer1kpop, color="Red", label="Divorces")
plt.grid()
plt.xlim(2000, 2017)
plt.ylabel('Percent of the population')
plt.title('Comparison')
plt.xlabel('Year')
plt.tight_layout(0)
plt.xticks(ticks = x_axis, labels = x_axis)
plt.legend()

plt.savefig("Comparison.png")
